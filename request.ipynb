# %%
import requests

# %%
r = requests.get('https://icd.who.int/es')

# %%
r.content
# Out:
# b'\xef\xbb\xbf<!DOCTYPE html>\r\n<html>\r\n<head>\r\n    <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no" />\r\n    <title>CIE-11</title>\r\n    <link rel="icon" type="image/png" href="/img/icd11icon.png">\r\n    <link href="../css/materialize.min.css" type="text/css" rel="stylesheet" media="screen,projection" />\r\n    <link href="../css/my.css" type="text/css" rel="stylesheet" media="screen,projection" />\r\n    <link href="../css/style.css" type="text/css" rel="stylesheet" media="screen,projection" />\r\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/highlight.js/8.5/styles/default.min.css">\r\n    <style type="text/css">\r\n        footer.page-footer {\r\n            background-color: aliceblue;\r\n        }\r\n    </style>\r\n</head>\r\n<body>\r\n    <div id="wrapper">\r\n        <div id="index-banner" class="parallax-conta
# ...
